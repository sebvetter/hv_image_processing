# %%
import os
import sys
sys.path.append('./modules/')
import processing, image_handler, run_handler
import numpy as np
import pandas as pd
import cv2
import rawpy
import re
import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib as mpl
import skimage
from scipy.ndimage import gaussian_filter
from PIL import Image, ExifTags
import exifread
import imageio
from datetime import timedelta
import pickle
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import scipy.fft
from sklearn.ensemble import RandomForestClassifier
from functools import partial
from minisom import MiniSom
import json
from datetime import datetime

# %%
# file = 'Y:\\Cathode\\LocalHVTest\\SpareMesh_3_230505\\NIKON\\Run2\\DSC_2875.JPG'
file = 'Y:\\Cathode\\LocalHVTest\\SpareMesh\\spareMesh_NIKON\\Test2\\DSC_1969.JPG'
pic = image_handler.Picture(file=file)
img = pic.load_image()
plt.imshow(img)
plt.show()

# %%
pic.get_contour_data()

# %%
processed = pic.get_processed_image()
fig, ax = plt.subplots(1, 2, figsize=(12, 7))
ax[0].imshow(processed)
ax[1].imshow(processed)
for c in pic.contours:
    ax[1].plot(c[:,:,0], c[:,:,1])
