# %%
import cv2
import exifread
import matplotlib.pyplot as plt

# %%
calibration_file = 'C:\\Users\\tm3408\\Desktop\\phd\\workspace\\data\\hv_mesh_test\\images\\DSC_1915.JPG'
ex_img = cv2.imread(calibration_file, cv2.IMREAD_COLOR)
with open(calibration_file, 'rb') as f:
    tags = exifread.process_file(f)
print(tags['EXIF DateTimeOriginal'])
plt.imshow(ex_img)
plt.show()
# Out:
# 2023:04:20 13:32:11
